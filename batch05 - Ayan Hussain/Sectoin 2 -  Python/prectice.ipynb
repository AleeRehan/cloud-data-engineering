# %%
for i in range(4): # 0,1,2,3,
    for j in range(4): # 0,1,2,3
        print(i,j)
        #break
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
# 1 0
# 1 1
# 1 2
# 1 3
# 2 0
# 2 1
# 2 2
# 2 3
# 3 0
# 3 1
# 3 2
# 3 3

# %%
print("Ali")
# Out:
# Ali

# %%
matrix = [[2,11,7,12],
          [5,2,9,15],
          [8,3,10,42]]

for i in matrix:
    for j in i:
        print(j, end = " ")
    #print(sum(i))
# Out:
# 2 11 7 12 5 2 9 15 8 3 10 42

# %%
sentence = input("Enter a sentence: ")
words = sentence.lower().split()

freq = {}
for word in words:
    freq[word] = freq.get(word, 0) + 1

print("Word Frequency:")
for word, count in freq.items():
    print(f"{word}: {count}")

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()

freq = {}
for word in words:
    if word in freq:
        freq[word] = freq[word] + 1
    else:
        freq[word] = 1

print("Word Frequency:")
for word in freq:
    print(word, ":", freq[word])

# %%
pip install --upgrade ipykernel
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipykernel in c:\users\ali\appdata\roaming\python\python312\site-packages (7.3.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (9.14.1)
# Requirement already satisfied: jupyter-client>=8.9.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (8.9.1)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (1.7.2)
# Requirement already satisfied: packaging>=22 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (26.2)
# Requirement already satisfied: psutil>=5.7 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (6.5.7)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipykernel) (5.15.1)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ali\appdata\roaming\python\python312\site-packages (from jupyter-client>=8.9.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from jupyter-client>=8.9.0->ipykernel) (4.15.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ali\appdata\roaming\python\python312\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\ali\appdata\roaming\python\python312\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.7)
# Requirement already satisfied: wcwidth in c:\users\ali\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\ali\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ali\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\ali\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
python.exe -m pip install --upgrade pip
# Out:
#   Cell In[3], line 1
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax
